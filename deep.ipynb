# %%
# ======================================================
# VISUALIZACIÓN INICIAL DEL DATASET RDE (Pretoria)
# Autor: Sergio Andrés Zapata Gómez
# Ingeniería Mecánica - Deep Learning
# ======================================================

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Configuración general
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("viridis")

# ======================================================
# 1. Cargar los tres archivos del dataset
# ======================================================
# Rutas de los archivos CSV
files = {
    "Toyota Etios": "public-etios.csv",
    "Ford Figo": "public-figo.csv",
    "Isuzu FTR850": "public-rrv.csv"
}

datasets = {}
for name, path in files.items():
    if os.path.exists(path):
        df = pd.read_csv(path)
        datasets[name] = df
        print(f"{name} cargado correctamente. ({df.shape[0]:,} filas, {df.shape[1]} columnas)")
    else:
        print(f" No se encontró el archivo: {path}")

# ======================================================
# 2. Exploración general
# ======================================================
for name, df in datasets.items():
    print(f"\n===== {name.upper()} =====")
    print(df.info())
    print("\nPrimeras filas:")
    print(df.head(3))
    print("\nEstadísticas:")
    print(df.describe().T.head(10))

# ======================================================
# 3. Visualizaciones básicas
# ======================================================
for name, df in datasets.items():
    print(f"\n Generando gráficos para: {name}")

    # Buscar variables relevantes automáticamente
    col_nox = next((c for c in df.columns if "nox" in c.lower()), None)
    col_speed = next((c for c in df.columns if "speed" in c.lower()), None)
    col_rpm = next((c for c in df.columns if "rpm" in c.lower()), None)

    # --- Histograma de NOx ---
    if col_nox:
        plt.figure(figsize=(8,5))
        sns.histplot(df[col_nox], bins=50, kde=True)
        plt.title(f"Distribución de NOx - {name}")
        plt.xlabel(f"{col_nox} (ppm)")
        plt.ylabel("Frecuencia")
        plt.tight_layout()
        plt.show()

    # --- Velocidad vs NOx ---
    if col_nox and col_speed:
        plt.figure(figsize=(8,5))
        sns.scatterplot(data=df, x=col_speed, y=col_nox, alpha=0.3)
        plt.title(f"{name}: Velocidad vs NOx")
        plt.xlabel(f"{col_speed} (km/h)")
        plt.ylabel(f"{col_nox} (ppm)")
        plt.tight_layout()
        plt.show()

    # --- Matriz de correlación (numérica) ---
    plt.figure(figsize=(10,6))
    sns.heatmap(df.corr(numeric_only=True), cmap="viridis", annot=False)
    plt.title(f"Matriz de correlación - {name}")
    plt.tight_layout()
    plt.show()

# ======================================================
# 4. Comparación general entre vehículos
# ======================================================
sizes = {name: df.shape[0] for name, df in datasets.items()}
plt.figure(figsize=(6,4))
plt.bar(sizes.keys(), sizes.values(), color='teal')
plt.title("Número de registros por vehículo")
plt.ylabel("Cantidad de filas")
plt.tight_layout()
plt.show()

print("\n Visualización inicial completa para todos los archivos RDE.")
# Out:
# Toyota Etios cargado correctamente. (272,008 filas, 47 columnas)
# Ford Figo cargado correctamente. (167,559 filas, 47 columnas)
# Isuzu FTR850 cargado correctamente. (749,039 filas, 48 columnas)
#
# ===== TOYOTA ETIOS =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272008 entries, 0 to 272007
# Data columns (total 47 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   date               272008 non-null  object
#  1   trip               272008 non-null  int64
#  2   driver             272008 non-null  int64
#  3   route              272008 non-null  int64
#  4   load               272008 non-null  int64
#  5   coldStart          272008 non-null  bool
#  6   gps_lat            272008 non-null  float64
#  7   gps_lon            272008 non-null  float64
#  8   gps_alt            272008 non-null  float64
#  9   gps_speed          272008 non-null  float64
#  10  humidity           272008 non-null  float64
#  11  pressure           272008 non-null  int64
#  12  temp               272008 non-null  float64
#  13  rpm                272008 non-null  int64
#  14  speed_vehicle      272008 non-null  float64
#  15  throttle           272008 non-null  float64
#  16  manifold_pressure  272008 non-null  float64
#  17  manifold_temp      272008 non-null  float64
#  18  coolant_temp       272008 non-null  float64
#  19  fuel_flow          272008 non-null  float64
#  20  fuel_rate          272008 non-null  float64
#  21  air_fuel_ratio     272008 non-null  float64
#  22  exh_humidity       272008 non-null  float64
#  23  exh_mass_flow      272008 non-null  float64
#  24  exh_flow_scfm      272008 non-null  float64
#  25  exh_flow_ls        272008 non-null  float64
#  26  exh_temp           272008 non-null  float64
#  27  CO2_amb_conc       272008 non-null  float64
#  28  CO_amb_conc        272008 non-null  float64
#  29  NO_amb_conc        272008 non-null  float64
#  30  NO2_amb_conc       272008 non-null  float64
#  31  O2_amb_conc        272008 non-null  float64
#  32  CO2_wet_conc       272008 non-null  float64
#  33  CO_wet_conc        272008 non-null  float64
#  34  NO_wet_conc        272008 non-null  float64
#  35  NO2_wet_conc       272008 non-null  float64
#  36  NOx_wet_conc       272008 non-null  float64
#  37  O2_wet_conc        272008 non-null  float64
#  38  CO2_mass           272008 non-null  float64
#  39  CO_mass            272008 non-null  float64
#  40  NO_mass            272008 non-null  float64
#  41  NO2_mass           272008 non-null  float64
#  42  NOx_mass           272008 non-null  float64
#  43  O2_mass            272008 non-null  float64
#  44  NO_mass_cor        272008 non-null  float64
#  45  NO2_mass_cor       272008 non-null  float64
#  46  NOx_mass_cor       272008 non-null  float64
# dtypes: bool(1), float64(39), int64(6), object(1)
# memory usage: 95.7+ MB
# None
#
# Primeras filas:
#                        date  trip  driver  route  load  coldStart   gps_lat  \
# 0  2022-11-15T07:34:17.915Z     1       4      1     0       True -25.75374
# 1  2022-11-15T07:34:18.115Z     1       4      1     0       True -25.75374
# 2  2022-11-15T07:34:18.315Z     1       4      1     0       True -25.75374
#
#      gps_lon  gps_alt  gps_speed  ...  O2_wet_conc  CO2_mass  CO_mass  \
# 0  28.228008   1222.0        0.0  ...       2.9274     0.863  0.11817
# 1  28.228008   1222.0        0.0  ...       2.6813     0.859  0.11218
# 2  28.228008   1221.9        0.0  ...       2.4746     0.886  0.10825
#
#    NO_mass  NO2_mass  NOx_mass  O2_mass  NO_mass_cor  NO2_mass_cor  \
# 0  0.00108   0.00002   0.00111  0.19800      0.00107       0.00002
# 1  0.00106   0.00002   0.00109  0.17675      0.00104       0.00002
# 2  0.00111   0.00002   0.00113  0.16408      0.00109       0.00002
#
#    NOx_mass_cor
# 0       0.00109
# 1       0.00107
# 2       0.00111
#
# [3 rows x 47 columns]
#
# Estadísticas:
#               count         mean        std         min          25%  \
# trip       272008.0     5.357537   2.854318    1.000000     3.000000
# driver     272008.0     4.000000   0.000000    4.000000     4.000000
# route      272008.0     1.000000   0.000000    1.000000     1.000000
# load       272008.0     0.000000   0.000000    0.000000     0.000000
# gps_lat    272008.0   -25.760152   0.032811  -25.821444   -25.787374
# gps_lon    272008.0    28.252991   0.036358   28.195055    28.224813
# gps_alt    272008.0  1374.352879  80.962316    0.000000  1317.200000
# gps_speed  272008.0    40.430031  28.649177    0.000000    13.900000
# humidity   272008.0    46.118433   7.261386   31.300000    40.600000
# pressure   272008.0   868.961255   7.557751  848.000000   864.000000
#
#                    50%          75%          max
# trip          5.000000     8.000000    10.000000
# driver        4.000000     4.000000     4.000000
# route         1.000000     1.000000     1.000000
# load          0.000000     0.000000     0.000000
# gps_lat     -25.753013   -25.733849   -25.711016
# gps_lon      28.248884    28.283409    28.317741
# gps_alt    1363.800000  1422.600000  1561.900000
# gps_speed    43.300000    61.100000   140.200000
# humidity     44.400000    50.800000    69.700000
# pressure    870.000000   875.000000   885.000000
#
# ===== FORD FIGO =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167559 entries, 0 to 167558
# Data columns (total 47 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   date               167559 non-null  object
#  1   trip               167559 non-null  int64
#  2   driver             167559 non-null  int64
#  3   route              167559 non-null  int64
#  4   load               167559 non-null  int64
#  5   coldStart          167559 non-null  bool
#  6   gps_lat            167559 non-null  float64
#  7   gps_lon            167559 non-null  float64
#  8   gps_alt            167559 non-null  float64
#  9   gps_speed          167559 non-null  float64
#  10  humidity           167559 non-null  float64
#  11  pressure           167559 non-null  int64
#  12  temp               167559 non-null  float64
#  13  rpm                167559 non-null  int64
#  14  speed_vehicle      167559 non-null  float64
#  15  throttle           167559 non-null  float64
#  16  manifold_pressure  167559 non-null  float64
#  17  manifold_temp      167559 non-null  float64
#  18  coolant_temp       167559 non-null  float64
#  19  fuel_flow          167559 non-null  float64
#  20  fuel_rate          167559 non-null  float64
#  21  air_fuel_ratio     167559 non-null  float64
#  22  exh_humidity       167559 non-null  float64
#  23  exh_mass_flow      167559 non-null  float64
#  24  exh_flow_scfm      167559 non-null  float64
#  25  exh_flow_ls        167559 non-null  float64
#  26  exh_temp           167559 non-null  float64
#  27  CO2_amb_conc       167559 non-null  float64
#  28  CO_amb_conc        167559 non-null  float64
#  29  NO_amb_conc        167559 non-null  float64
#  30  NO2_amb_conc       167559 non-null  float64
#  31  O2_amb_conc        167559 non-null  float64
#  32  CO2_wet_conc       167559 non-null  float64
#  33  CO_wet_conc        167559 non-null  float64
#  34  NO_wet_conc        167559 non-null  float64
#  35  NO2_wet_conc       167559 non-null  float64
#  36  NOx_wet_conc       167559 non-null  float64
#  37  O2_wet_conc        167559 non-null  float64
#  38  CO2_mass           167559 non-null  float64
#  39  CO_mass            167559 non-null  float64
#  40  NO_mass            167559 non-null  float64
#  41  NO2_mass           167559 non-null  float64
#  42  NOx_mass           167559 non-null  float64
#  43  O2_mass            167559 non-null  float64
#  44  NO_mass_cor        167559 non-null  float64
#  45  NO2_mass_cor       167559 non-null  float64
#  46  NOx_mass_cor       167559 non-null  float64
# dtypes: bool(1), float64(39), int64(6), object(1)
# memory usage: 59.0+ MB
# None
#
# Primeras filas:
#                             date  trip  driver  route  load  coldStart  \
# 0  07/27/2021 10:03:03.131 +0200     1       3      1     0       True
# 1  07/27/2021 10:03:04.131 +0200     1       3      1     0       True
# 2  07/27/2021 10:03:05.131 +0200     1       3      1     0       True
#
#      gps_lat    gps_lon  gps_alt  gps_speed  ...  O2_wet_conc  CO2_mass  \
# 0 -25.753279  28.227495   1355.9        0.0  ...      22.9474      -0.0
# 1 -25.753279  28.227495   1355.9        0.0  ...      22.9490      -0.0
# 2 -25.753279  28.227495   1355.9        0.0  ...      22.9468      -0.0
#
#    CO_mass  NO_mass  NO2_mass  NOx_mass  O2_mass  NO_mass_cor  NO2_mass_cor  \
# 0 -0.00004     -0.0      -0.0      -0.0 -0.03534         -0.0          -0.0
# 1 -0.00004     -0.0      -0.0      -0.0 -0.03427         -0.0          -0.0
# 2 -0.00004     -0.0      -0.0      -0.0 -0.03455         -0.0          -0.0
#
#    NOx_mass_cor
# 0          -0.0
# 1          -0.0
# 2          -0.0
#
# [3 rows x 47 columns]
#
# Estadísticas:
#               count         mean        std          min          25%  \
# trip       167559.0    15.291157   8.617454     1.000000     8.000000
# driver     167559.0     2.030503   0.821255     1.000000     1.000000
# route      167559.0     1.000000   0.000000     1.000000     1.000000
# load       167559.0     0.000000   0.000000     0.000000     0.000000
# gps_lat    167559.0   -25.760533   0.033106   -25.821444   -25.787642
# gps_lon    167559.0    28.254070   0.036384    28.195040    28.225285
# gps_alt    167559.0  1374.223818  72.779548  1266.800000  1315.100000
# gps_speed  167559.0    39.380799  26.950576     0.000000    15.200000
# humidity   167559.0    34.783164  18.517377     6.200000    20.400000
# pressure   167559.0   878.879941   7.867318   858.000000   874.000000
#
#                    50%          75%          max
# trip         15.000000    23.000000    30.000000
# driver        2.000000     3.000000     3.000000
# route         1.000000     1.000000     1.000000
# load          0.000000     0.000000     0.000000
# gps_lat     -25.753027   -25.733962   -25.711013
# gps_lon      28.250793    28.285602    28.317732
# gps_alt    1363.600000  1421.300000  1552.900000
# gps_speed    42.800000    59.800000   132.200000
# humidity     31.700000    46.800000    76.200000
# pressure    880.000000   885.000000   895.000000
#
# ===== ISUZU FTR850 =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 749039 entries, 0 to 749038
# Data columns (total 48 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   date               749039 non-null  object
#  1   trip               749039 non-null  int64
#  2   driver             749039 non-null  int64
#  3   route              749039 non-null  int64
#  4   load               749039 non-null  int64
#  5   coldStart          749039 non-null  bool
#  6   gps_lat            749039 non-null  float64
#  7   gps_lon            749039 non-null  float64
#  8   gps_alt            749039 non-null  float64
#  9   gps_speed          749039 non-null  float64
#  10  humidity           749039 non-null  float64
#  11  pressure           749039 non-null  int64
#  12  temp               749039 non-null  float64
#  13  rpm                749039 non-null  int64
#  14  speed_vehicle      749039 non-null  float64
#  15  throttle           749039 non-null  float64
#  16  manifold_pressure  749039 non-null  float64
#  17  manifold_temp      749039 non-null  float64
#  18  coolant_temp       749039 non-null  float64
#  19  fuel_flow          749039 non-null  float64
#  20  fuel_rate          749039 non-null  float64
#  21  air_fuel_ratio     749039 non-null  float64
#  22  exh_humidity       749039 non-null  float64
#  23  exh_mass_flow      749039 non-null  float64
#  24  exh_flow_scfm      749039 non-null  float64
#  25  exh_flow_ls        749039 non-null  float64
#  26  exh_temp           749039 non-null  float64
#  27  mass_flow_rate     749039 non-null  float64
#  28  CO2_amb_conc       749039 non-null  float64
#  29  CO_amb_conc        749039 non-null  float64
#  30  NO_amb_conc        749039 non-null  float64
#  31  NO2_amb_conc       749039 non-null  float64
#  32  O2_amb_conc        749039 non-null  float64
#  33  CO2_wet_conc       749039 non-null  float64
#  34  CO_wet_conc        749039 non-null  float64
#  35  NO_wet_conc        749039 non-null  float64
#  36  NO2_wet_conc       749039 non-null  float64
#  37  NOx_wet_conc       749039 non-null  float64
#  38  O2_wet_conc        749039 non-null  float64
#  39  CO2_mass           749039 non-null  float64
#  40  CO_mass            749039 non-null  float64
#  41  NO_mass            749039 non-null  float64
#  42  NO2_mass           749039 non-null  float64
#  43  NOx_mass           749039 non-null  float64
#  44  O2_mass            749039 non-null  float64
#  45  NO_mass_cor        749039 non-null  float64
#  46  NO2_mass_cor       749039 non-null  float64
#  47  NOx_mass_cor       749039 non-null  float64
# dtypes: bool(1), float64(40), int64(6), object(1)
# memory usage: 269.3+ MB
# None
#
# Primeras filas:
#                             date  trip  driver  route  load  coldStart  \
# 0  02/02/2021 10:09:42.773 +0200     1       1      1     0      False
# 1  02/02/2021 10:09:43.773 +0200     1       1      1     0      False
# 2  02/02/2021 10:09:44.773 +0200     1       1      1     0      False
#
#      gps_lat    gps_lon  gps_alt  gps_speed  ...  O2_wet_conc  CO2_mass  \
# 0 -25.753752  28.227598   1385.7        0.0  ...      20.3128    -0.003
# 1 -25.753756  28.227598   1386.5        0.0  ...      20.4178    -0.003
# 2 -25.753759  28.227600   1387.3        0.0  ...      20.4781    -0.001
#
#    CO_mass  NO_mass  NO2_mass  NOx_mass  O2_mass  NO_mass_cor  NO2_mass_cor  \
# 0     -0.0 -0.00004      -0.0  -0.00005 -0.04616     -0.00004          -0.0
# 1     -0.0 -0.00005      -0.0  -0.00006 -0.05969     -0.00005          -0.0
# 2     -0.0 -0.00002      -0.0  -0.00002 -0.02427     -0.00002          -0.0
#
#    NOx_mass_cor
# 0      -0.00005
# 1      -0.00006
# 2      -0.00002
#
# [3 rows x 48 columns]
#
# Estadísticas:
#               count         mean         std         min          25%  \
# trip       749039.0    19.331964    6.872200    1.000000    14.000000
# driver     749039.0     1.000000    0.000000    1.000000     1.000000
# route      749039.0     1.000000    0.000000    1.000000     1.000000
# load       749039.0  2095.170612  922.920571    0.000000  1500.000000
# gps_lat    749039.0   -25.761804    0.033110  -25.821461   -25.788046
# gps_lon    749039.0    28.253615    0.036031   28.195122    28.226072
# gps_alt    749039.0  1379.563375   73.378608    0.000000  1319.400000
# gps_speed  749039.0    31.421193   22.706635    0.000000     9.600000
# humidity   749039.0    49.896501   11.714346   14.100000    41.100000
# pressure   749039.0   868.545020    7.855556  846.000000   864.000000
#
#                    50%          75%          max
# trip         20.000000    25.000000    30.000000
# driver        1.000000     1.000000     1.000000
# route         1.000000     1.000000     1.000000
# load       1500.000000  3000.000000  3000.000000
# gps_lat     -25.756105   -25.735058   -25.711006
# gps_lon      28.250822    28.281676    28.317736
# gps_alt    1370.400000  1425.900000  1560.400000
# gps_speed    32.800000    49.400000    89.500000
# humidity     48.100000    57.000000    97.400000
# pressure    870.000000   874.000000   886.000000
#
#  Generando gráficos para: Toyota Etios
#  Generando gráficos para: Ford Figo
#  Generando gráficos para: Isuzu FTR850
#  Visualización inicial completa para todos los archivos RDE.
